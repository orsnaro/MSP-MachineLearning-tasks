# %% [markdown]
# # **Importing Libraries :-**
#
# ---

# %%
import seaborn as sns
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
sns.set(rc={'figure.figsize': [7, 7]}, font_scale=1.2)#same as sns.set_theme()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# # **Univariate Plots :-**
#
# >deals with single variable and contains one type of plot :-
#    1.   count plot.
#
#
# ---

# %% [markdown]
# ## **Count Plots :-**
#
#
# > Frequency (counting) of categroical data.

# %%
df_penguins = sns.load_dataset('penguins') #loads example data set from internet github ( needs internet)
df_penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df_penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df_penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.countplot(x='species',data=df_penguins)
# Out:
# <AxesSubplot: xlabel='species', ylabel='count'>

# %%
sns.countplot(x='island',data=df_penguins)
# Out:
# <AxesSubplot: xlabel='island', ylabel='count'>

# %%
sns.countplot(x='sex',data=df_penguins)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='species',data=df_penguins,hue='sex')
# Out:
# <AxesSubplot: xlabel='species', ylabel='count'>

# %%
sns.countplot(x='island',data=df_penguins,hue='species')
df_penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df_tips = sns.load_dataset('tips')
df_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df_tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='day',data=df_tips)
# Out:
# <AxesSubplot: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='sex',data=df_tips)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex',data=df_tips,hue='smoker')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex',data=df_tips,hue='time')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex',data=df_tips,hue='day')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='time',data=df_tips)
# Out:
# <AxesSubplot: xlabel='time', ylabel='count'>

# %%
sns.countplot(x='time',data=df_tips,hue='size')
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # **Bivariate Plots :-**
#
# >deals with two variables (one catigrical and one numerical) and contains five types plots :-
#    1.   bar plots
#    2.   box plots
#    3.   violin plots
#    4.   swarp plots
#    5.   strip plots
#
#
# ---

# %% [markdown]
# ### Bar Plots:-
#
#
# >is a general plot that allows you to aggregate the categorical data based off some function, by default the mean
# ---

# %%
df_penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
sns.barplot(x='species',y='body_mass_g',data=df_penguins , estimator= 'mean' , hue = 'sex')
#gets the mean of body mass for each specie
# Out:
# <AxesSubplot: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species',y='body_mass_g',data=df_penguins,estimator=np.mean)
# Out:
# <AxesSubplot: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='sex',y='flipper_length_mm',data=df_penguins,estimator=np.max)
#estimator can be:

      #estimator=np.mean
      #estimator=np.std
      #estimator=np.median
      #estimator=np.max
      #estimator=np.min
      #estimator=np.sum
      # or strings of them
# Out:
# <AxesSubplot: xlabel='sex', ylabel='flipper_length_mm'>

# %%
sns.barplot(x='sex',y='flipper_length_mm',data=df_penguins,estimator=np.min)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='flipper_length_mm'>

# %%
df_titanic = sns.load_dataset('titanic')
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.barplot(x='sex',y='survived',data=df_titanic,estimator=np.sum )

# %%
sns.barplot(x='class',y='survived',data=df_titanic,estimator=np.sum )

# %%
sns.barplot(x='class',y='survived',data=df_titanic,estimator=np.mean )

# %% [markdown]
# ## **Box Plots :-**
#
#
# > A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
#
#
# ---

# %%
df_penguins.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
sns.boxplot(x='species', y="body_mass_g", data=df_penguins)

# %%
sns.boxplot(x='species', y="body_mass_g", data=df_penguins,hue='sex')

# %%
sns.boxplot(x='species', y="body_mass_g", data=df_penguins,hue='island')

# %%
sns.boxplot(x='sex', y="flipper_length_mm", data=df_penguins)

# %%
sns.boxplot(x='sex', y="flipper_length_mm", data=df_penguins,hue='species')

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.boxplot(x='alive', y="age", data=df_titanic)

# %%
sns.boxplot(x='alive', y="age", data=df_titanic,hue='sex')

# %%
sns.boxplot(x='alive', y="age", data=df_titanic,hue='class')

#show the out liers of not alive and thirs class from the dataframe it self
df = df_titanic[(df_titanic['alive'] != 'yes') & (df_titanic['class'] == 'Third')].sort_values(by = 'age' , ascending = False )
df.groupby('age').head(20)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 851         0       3    male  74.0      0      0   7.7750        S  Third
# 116         0       3    male  70.5      0      0   7.7500        Q  Third
# 280         0       3    male  65.0      0      0   7.7500        Q  Third
# 326         0       3    male  61.0      0      0   6.2375        S  Third
# 94          0       3    male  59.0      0      0   7.2500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 205         0       3  female   2.0      0      1  10.4625        S  Third
# 824         0       3    male   2.0      4      1  39.6875        S  Third
# 7           0       3    male   2.0      3      1  21.0750        S  Third
# 386         0       3    male   1.0      5      2  46.9000        S  Third
# 164         0       3    male   1.0      4      1  39.6875        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(x='sex', y="age", data=df_titanic)

# %%
sns.boxplot(x='sex', y="age", data=df_titanic,hue='alive')

# %% [markdown]
# ## **Volin Plots :-**
#
# > Same to box plot in properties and chart meaning as it shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable but the chart shape looks like violin,the violin plot features a kernel density estimation of the underlying distribution.
# ---

# %%
df_penguins.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
sns.violinplot(x='species', y="body_mass_g", data=df_penguins)

# %%
sns.violinplot(x='species', y="body_mass_g", data=df_penguins,hue='sex')

# %%
#While using hue parameter in violinplot you can use split parameter  
#There must be exactly two hue levels to use split 
sns.violinplot(x='species', y="body_mass_g", data=df_penguins,hue='sex',split=True)

# %%
sns.violinplot(x='sex', y="flipper_length_mm", data=df_penguins)

# %%
sns.violinplot(x='sex', y="flipper_length_mm", data=df_penguins,hue='species')

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.violinplot(x='alive', y="age", data=df_titanic)

# %%
sns.violinplot(x='alive', y="age", data=df_titanic,hue='sex',split=True)

# %%
sns.violinplot(x='alive', y="age", data=df_titanic,hue='class')

# %% [markdown]
# ##**Strip Plots:-**
# >Strip plot draws a scatterplot where one variable is categorical and can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# >Disadventage of Strip Plots  is the scatters can be overlapped
# ---

# %%
sns.stripplot(x="species", y="body_mass_g", data=df_penguins)
# Out:
# <AxesSubplot: xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(x="species", y="body_mass_g", data=df_penguins,hue='sex')

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.stripplot(x="alive", y="age", data=df_titanic)

# %%
sns.stripplot(x="alive", y="age", data=df_titanic,hue='sex')

# %%
sns.stripplot(x="alive", y="age", data=df_titanic,hue='class')
# Out:
# <AxesSubplot: xlabel='alive', ylabel='age'>

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.stripplot(x="sex", y="total_bill", data=df_tips)

# %%
sns.stripplot(x="sex", y="total_bill", data=df_tips,hue='time')

# %%
sns.stripplot(x="sex", y="total_bill", data=df_tips,hue='smoker')

# %%
sns.stripplot(x="sex", y="total_bill", data=df_tips,hue='day')

# %% [markdown]
# ##**Swarm Plots :-**
# >Swarp Plots draw a categorical scatterplot with non-overlapping points and swarp Plots similar to strip plots, but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, but it does not scale well to large numbers of observations. This style of plot is sometimes called a “beeswarm”.
#
# >Swarm plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
#
# ---

# %%
df_penguins.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
sns.swarmplot(x="species", y="bo)dy_mass_g", data=df_penguins)

# %%
sns.stripplot(x="species", y="body_mass_g", data=df_penguins)

# %%
sns.swarmplot(x="species", y="body_mass_g", data=df_penguins,hue='sex')

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.swarmplot(x="alive", y="age", data=df_titanic)

# %%
sns.swarmplot(x="alive", y="age", data=df_titanic,hue='sex')

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.swarmplot(x="sex", y="total_bill", data=df_tips)

# %%
sns.swarmplot(x="sex", y="total_bill", data=df_tips,hue='smoker')

# %%
sns.swarmplot(x="sex", y="total_bill", data=df_tips,hue='time')

# %%
sns.swarmplot(x="sex", y="total_bill", data=df_tips,hue='day')

# %% [markdown]
# ### my prac area

# %%
import matplotlib as plt 
import seaborn as sns 
# %matplotlib inline
