# %% [markdown]
# #**importing Libraries :-**
#
# ---

# %%
import seaborn as sns
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
#allowing your chart to printed in the notebook
# %matplotlib inline
sns.set(rc={'figure.figsize': [7, 7]}, font_scale=1.2)

# %%
# sns.get_dataset_names()

# %% [markdown]
# # **Univariate Plots :-**
#
# >deals with single variable and contains two types plots :-
#    1.   dist plot
#    2.   kde plot
#    3.   hist plot
#
#
# ---

# %% [markdown]
# ##**1.distplots :-**
#
#
# > deals with frequancy (count) of single variable
#
#
# ---

# %%
#Loading built-in dataset in seeborn
df_titanic = sns.load_dataset('titanic')
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.displot(df_titanic['survived'])

# %%
#Change the color a little bit, valid options for colors: r, g, b, c, m, y, k
#you can add your height and aspect ration that can be as zoom degree
sns.displot(df_titanic['pclass'],kde = False, color='m',height=8,aspect=1.2)

# %%
sns.displot(df_titanic['fare'], color='c',height=8,aspect=1.2)

# %%
sns.displot(df_titanic['age'], color='c',height=5,aspect=1.2)

# %%
sns.displot(df_titanic['age'], color='c',kde=True,height=5,aspect=1.2)

# %%
#you can increase range in your chart using bins
sns.displot(df_titanic['age'], color='c',bins=50,height=5,aspect=1.2)

# %%
df_tips = sns.load_dataset('tips')
df_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df_tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(df_tips['total_bill'], color='k')

# %%
sns.displot(df_tips['total_bill'], color='k',kde = True )

# %%
sns.displot(df_tips['tip'], color='r',height=6,aspect=1.1)

# %%
sns.displot(df_tips['tip'], color='r',height=6,aspect=1.1,bins=20, stat = trh)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [55], line 1
# ----> 1 sns.displot(df_tips['tip'], color='r',height=6,aspect=1.1,bins=20, stat = trh)
#
# NameError: name 'trh' is not defined

# %%
sns.displot(df_tips['size'], color='b')

# %% [markdown]
# ## **2.kdeplots :-**
#
# > kdeplots stand for Kernel Density Estimation plots. These KDE plots replace every single observation with a Gaussian (Normal) distribution centered around that value

# %%
sns.kdeplot(df_tips['total_bill'], color='k')

# %%
sns.kdeplot(df_tips['total_bill'], color='k',shade=True)

# %%
sns.kdeplot(df_tips['tip'], color='k')

# %%
sns.kdeplot(df_titanic['survived'], color='g',shade=True)

# %%
sns.kdeplot(df_titanic['age'], color='r',shade=True)

# %% [markdown]
# # **Bivariate Plots :-**
#
# >deals with two variables or more and contains two types plots :-
#    1.   join plot
#    2.   pair plot
#
#
# ---

# %% [markdown]
# ## **1.join plots :-**
#
#
# > Measure the relation , correlation and dependency between two vairiables only

# %%
sns.jointplot(x='total_bill',y='tip',data=df_tips,height=7,color='k') 
#no aspect in joinplot there is height only

# %%
#defult kind is scatter  
sns.jointplot(x='total_bill',y='tip',data=df_tips,height=7,color='k',kind='reg')

# %%
sns.jointplot(x='total_bill', y='tip', data=df_tips, kind='kde', height=8, color='k')

# %%
df_penguins = sns.load_dataset('penguins')
df_penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df_penguins.describe()

# %%
df_penguins.head()

# %%
sns.displot(df_penguins['flipper_length_mm'])

# %%
sns.displot(df_penguins['body_mass_g'])

# %%
sns.jointplot(x='body_mass_g',y='flipper_length_mm',data=df_penguins,height=7,color='r')

# %%
sns.jointplot(x='body_mass_g',y='flipper_length_mm',data=df_penguins,height=7,color='r',kind='hex' ,alpha= 0.5)

# %%
sns.jointplot(x='body_mass_g',y='flipper_length_mm',data=df_penguins,height=7,color='r',kind='kde')

# %%
sns.jointplot(x='body_mass_g',y='flipper_length_mm',data=df_penguins,height=7,color='r',kind='hist')

# %%
sns.jointplot(x='body_mass_g',y='flipper_length_mm',data=df_penguins,height=7,color='r',kind='reg')

# %% [markdown]
# ## **2.pair plots:-**
#
# >Measure the relation , correlation and dependency between all numerical vairiables

# %%
df_tips.head()

# %%
sns.pairplot(df_tips,height=4,aspect=1.2)

# %%
sns.pairplot(df_tips,height=4,aspect=1.2,hue='time')

# %%
sns.pairplot(tips, vars=['total_bill', 'tip'], height=4, aspect=1.2)

# %%
sns.pairplot(tips, vars=['total_bill', 'tip'], height=4, aspect=1.2,hue='day')

# %%
df_penguins.head()

# %%
sns.pairplot(df_penguins)

# %%
sns.pairplot(df_penguins, vars=['body_mass_g','flipper_length_mm'], height=4, aspect=1.2,hue='sex' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [57], line 1
# ----> 1 sns.pairplot(df_penguins, vars=['body_mass_g','flipper_length_mm'], height=4, aspect=1.2,hue='sex' , split = True)
#
# TypeError: pairplot() got an unexpected keyword argument 'split'

# %%
df_titanic.head()

# %%
sns.pairplot(df_titanic)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
